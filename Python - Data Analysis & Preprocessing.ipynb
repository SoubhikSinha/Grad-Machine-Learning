# %% [markdown]
# ### <b>Part I : Data Analysis & Preprocessing</b>

# %% [markdown]
# In this section, we will focus on data analysis and preprocessing.

# %% [markdown]
# <b>DATASETS</b> :
#
# Choose <b>TWO</b> datasets from the ‘noisy_datasets’ folder provided at UBlearns: </br>
# 1. Penguins Dataset from the <b>‘noisy_datasets’</b> folder. This dataset is slightly different from the
#    one provided in A0.
# 2. One more dataset from the <b>‘noisy_datasets’</b> folder

# %% [markdown]
# NOTE : First, commands will be executed on the `penguins.csv` dataset. Later on, all the steps will be covered for the other dataset
#
# <b>TASK</b> :

# %% [markdown]
# 1 🔽. Import required libraries (not allowed: scikit-learn or any other libraries
# with in-built functions that help to implement ML methods)

# %%
# For the time being we are importing the most useful libraries for data analysis
# later on as per the requirements will be importing / loading for appropriate
# libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 2 🔽. Read, preprocess, and print the main statistics about the dataset (you can reuse your code from A0 with a proper citation)

# %%
# Let us try to import / load the "penguins.csv" dataset

# Because this is Google Colab - we need to import the dataset from
# Google Drive. For that we have to mount the drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Importing / Loading dataset

penguins_df = pd.read_csv("/content/drive/MyDrive/Datasets/penguins.csv")

# %%
# Let us have a look to the dataset loaded

penguins_df
# Out:
#        species     island  calorie requirement  average sleep duration  \
# 0       Adelie  Torgersen                 6563                      11
# 1       Adelie  Torgersen                 4890                      14
# 2       Adelie  Torgersen                 7184                      11
# 3       Adelie  Torgersen                 4169                       8
# 4       Adelie  Torgersen                 4774                       8
# ..         ...        ...                  ...                     ...
# 339  Chinstrap      Dream                 4826                      11
# 340  Chinstrap      Dream                 4111                       9
# 341  Chinstrap      Dream                 7049                      10
# 342  Chinstrap      Dream                 4705                       7
# 343  Chinstrap      Dream                 6098                       7
#
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  gender  \
# ...

# %%
# We want to know the shape of the dataset

penguins_df.shape
# Out:
# (344, 10)

# %%
# Printing the main statistics of the dataset - including mean, standard
# deviation, and other relevant statistics

# We have taken this piece of code from "Assignment 0"

penguins_df.describe()
# Out:
#        calorie requirement  average sleep duration  bill_length_mm  \
# count           344.000000              344.000000      337.000000
# mean           5270.002907               10.447674       45.494214
# std            1067.959116                2.265895       10.815787
# min            3504.000000                7.000000       32.100000
# 25%            4403.000000                9.000000       39.500000
# 50%            5106.500000               10.000000       45.100000
# 75%            6212.750000               12.000000       49.000000
# max            7197.000000               14.000000      124.300000
#
#        bill_depth_mm  flipper_length_mm  body_mass_g         year
# count     333.000000         336.000000   339.000000   342.000000
# mean       18.018318         197.764881  4175.463127  2008.035088
# std         9.241384          27.764491   858.713267     0.816938
# min        13.100000          10.000000   882.000000  2007.000000
# ...

# %%
# Lets print the columns of the dataset

# We have taken this piece of code form "Assignment 0"

print(penguins_df.columns.tolist())
# Out:
# ['species', 'island', 'calorie requirement', 'average sleep duration', 'bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g', 'gender', 'year']

# %%
# Let us see the first 15 rows of the dataset - we just want to see a sample of
# the dataset (considering it as the population)

# We have taken this piece of code form "Assignment 0"

penguins_df.head(15)
# Out:
#    species     island  calorie requirement  average sleep duration  \
# 0   Adelie  Torgersen                 6563                      11
# 1   Adelie  Torgersen                 4890                      14
# 2   Adelie  Torgersen                 7184                      11
# 3   Adelie  Torgersen                 4169                       8
# 4   Adelie  Torgersen                 4774                       8
# 5   Adelie  Torgersen                 4403                      13
# 6   Adelie  Torgersen                 5071                      11
# 7   Adelie  Torgersen                 6799                       9
# 8   Adelie  Torgersen                 5593                       8
# 9   Adelie  Torgersen                 6275                       7
# 10  Adelie  Torgersen                 5135                      10
# 11  Adelie  Torgersen                 6021                       7
# 12  Adelie  Torgersen                 6644                      12
# ...

# %% [markdown]
# 3 🔽. Handle missing entries. Possible solutions: </br>
#
#   • Drop rows with missing entries. If you have a large dataset and only a few missing features, it may be acceptable to drop the rows containing missing values. </br>
#   • Impute missing data. Replace the missing entries with the mean/median/mode of the feature. You can use K-Nearest Neighbor algorithm to find the matching sample.

# %%
# As the "penguins" datatset is not very large - we will try to impute
# the messing data using the mean of the features

# Lets have a copy of the dataset

pf_df_copy = penguins_df.copy(deep=True)

# %%
features_list = pf_df_copy.columns.tolist()
print(features_list)
# Out:
# ['species', 'island', 'calorie requirement', 'average sleep duration', 'bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g', 'gender', 'year']

# %%
# Drop the categorical features for the time being from the list

features_list.remove("species")
features_list.remove("island")
features_list.remove("gender")

# %%
print(features_list)
# Out:
# ['calorie requirement', 'average sleep duration', 'bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g', 'year']

# %%
features_list.remove("year")

# %%
print(features_list)
# Out:
# ['calorie requirement', 'average sleep duration', 'bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']

# %%
# Lets find the mean values of the fetures left in the dataset

features_mean = []

for i in features_list:
  features_mean.append(pf_df_copy[i].mean())

# %%
print(features_mean)
# Out:
# [5270.002906976744, 10.44767441860465, 45.49421364985163, 18.018318318318318, 197.76488095238096, 4175.463126843658]

# %%
# Let replace "NaN" values with the mean values we got

for i,j in zip(features_list, features_mean):
    pf_df_copy[i].fillna(value = j, inplace = True)

# %%
# Lets have a look to the modified dataset

pf_df_copy
# Out:
#        species     island  calorie requirement  average sleep duration  \
# 0       Adelie  Torgersen                 6563                      11
# 1       Adelie  Torgersen                 4890                      14
# 2       Adelie  Torgersen                 7184                      11
# 3       Adelie  Torgersen                 4169                       8
# 4       Adelie  Torgersen                 4774                       8
# ..         ...        ...                  ...                     ...
# 339  Chinstrap      Dream                 4826                      11
# 340  Chinstrap      Dream                 4111                       9
# 341  Chinstrap      Dream                 7049                      10
# 342  Chinstrap      Dream                 4705                       7
# 343  Chinstrap      Dream                 6098                       7
#
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  gender  \
# ...

# %%
# We can see that the features containing categorical values
# still have 'NaN' values in them. Thus, we have to replace
# those with appropriate values.

# Hence, we are using 'ffill' method. This method fills the missing values
# with the value that comes before it in the dataset

pf_df_copy['gender'] = pf_df_copy['gender'].fillna(method = 'ffill')

# %%
pf_df_copy
# Out:
#        species     island  calorie requirement  average sleep duration  \
# 0       Adelie  Torgersen                 6563                      11
# 1       Adelie  Torgersen                 4890                      14
# 2       Adelie  Torgersen                 7184                      11
# 3       Adelie  Torgersen                 4169                       8
# 4       Adelie  Torgersen                 4774                       8
# ..         ...        ...                  ...                     ...
# 339  Chinstrap      Dream                 4826                      11
# 340  Chinstrap      Dream                 4111                       9
# 341  Chinstrap      Dream                 7049                      10
# 342  Chinstrap      Dream                 4705                       7
# 343  Chinstrap      Dream                 6098                       7
#
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  gender  \
# ...

# %%
# We will apply the same to other features having categorical values

pf_df_copy['species'] = pf_df_copy['species'].fillna(method = 'ffill')
pf_df_copy['island'] = pf_df_copy['island'].fillna(method = 'ffill')

# %%
pf_df_copy
# Out:
#        species     island  calorie requirement  average sleep duration  \
# 0       Adelie  Torgersen                 6563                      11
# 1       Adelie  Torgersen                 4890                      14
# 2       Adelie  Torgersen                 7184                      11
# 3       Adelie  Torgersen                 4169                       8
# 4       Adelie  Torgersen                 4774                       8
# ..         ...        ...                  ...                     ...
# 339  Chinstrap      Dream                 4826                      11
# 340  Chinstrap      Dream                 4111                       9
# 341  Chinstrap      Dream                 7049                      10
# 342  Chinstrap      Dream                 4705                       7
# 343  Chinstrap      Dream                 6098                       7
#
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  gender  \
# ...

# %% [markdown]
# 4 🔽. Handle mismatched string formats.
#
#   For example, in the penguins dataset, the "Species" feature might appear as "Adelie" or "adelie," both of which refer to the same penguin species. These
#   variations should be standardized to a consistent format such as "Adelie" or "adelie" to ensure consistency.

# %%
# Here am converting all the categorical values of all the features
# into their lower case

feature_list = ['species', 'island', 'gender']

for i in feature_list:
  for j in range(0,pf_df_copy[i].count()):
    pf_df_copy[i][j] = pf_df_copy[i][j].lower()
# Out:
# <ipython-input-131-7ca47b7b683d>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pf_df_copy[i][j] = pf_df_copy[i][j].lower()

# %%
pf_df_copy
# Out:
#        species     island  calorie requirement  average sleep duration  \
# 0       adelie  torgersen                 6563                      11
# 1       adelie  torgersen                 4890                      14
# 2       adelie  torgersen                 7184                      11
# 3       adelie  torgersen                 4169                       8
# 4       adelie  torgersen                 4774                       8
# ..         ...        ...                  ...                     ...
# 339  chinstrap      dream                 4826                      11
# 340  chinstrap      dream                 4111                       9
# 341  chinstrap      dream                 7049                      10
# 342  chinstrap      dream                 4705                       7
# 343  chinstrap      dream                 6098                       7
#
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  gender  \
# ...

# %% [markdown]
# 5 🔽. Handle outliers. Detect and manage outliers within the dataset.
#
# For example, in the penguins dataset, while flipper lengths typically fall
# within the range of [180 – 210], certain entries might exhibit values like
# [10, 30]. These can be considered outliers. Possible solutions:</br>
#
# • Remove outliers. If there are just a few outliers is limited, you may
# eliminate the rows containing these outliers. </br>
# • Impute outliers. Replace the outliers with the mean/median/mode of the
# feature.

# %%
# Please note : outliers for features that contain categorical values
# doesn't make any sense. Thus, we will stick to the features that
# contain numerical values

# Lets see what all features have numerical values
print(features_list)
# Out:
# ['calorie requirement', 'average sleep duration', 'bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']

# %%
# We will first create box plots to see abnormal values

# NOTE : The value in "calorie requirement" column has string values. Thus, they
# need to be converted to decimal values

for i in range(0, pf_df_copy['calorie requirement'].count()):
  pf_df_copy['calorie requirement'][i] = float(pf_df_copy['calorie requirement'][i])
# Out:
# <ipython-input-134-a6780c10427a>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pf_df_copy['calorie requirement'][i] = float(pf_df_copy['calorie requirement'][i])

# %%
pf_df_copy
# Out:
#        species     island  calorie requirement  average sleep duration  \
# 0       adelie  torgersen                 6563                      11
# 1       adelie  torgersen                 4890                      14
# 2       adelie  torgersen                 7184                      11
# 3       adelie  torgersen                 4169                       8
# 4       adelie  torgersen                 4774                       8
# ..         ...        ...                  ...                     ...
# 339  chinstrap      dream                 4826                      11
# 340  chinstrap      dream                 4111                       9
# 341  chinstrap      dream                 7049                      10
# 342  chinstrap      dream                 4705                       7
# 343  chinstrap      dream                 6098                       7
#
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  gender  \
# ...

# %%
# Lets create boxplots

for i in features_list:
  print("\n\n\n"+i+" 🔽")
  plt.boxplot(pf_df_copy[i])
  plt.show()
# Out:
# calorie requirement 🔽
# average sleep duration 🔽
# bill_length_mm 🔽
# bill_depth_mm 🔽
# flipper_length_mm 🔽
# body_mass_g 🔽

# %%
# We need to remove all the outliers from all the features / columns
# Thus, we need a function for the same

def outliers_removal(feature):
    Q1 = np.percentile(feature, 25)
    Q3 = np.percentile(feature, 75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    cleaned_data = []
    # cleaned_data = [i for i in feature if lower_bound <= i <= upper_bound]
    for i in feature:
      if (lower_bound <= i <= upper_bound):
        cleaned_data.append(i)
      else:
        cleaned_data.append('NaN')

    return cleaned_data

# Now lets put this function into action !

for i in features_list:
  pf_df_copy[i] = outliers_removal(pf_df_copy[i])

# %%
# Lets print the dataset

pf_df_copy
# Out:
#        species     island  calorie requirement  average sleep duration  \
# 0       adelie  torgersen                 6563                      11
# 1       adelie  torgersen                 4890                      14
# 2       adelie  torgersen                 7184                      11
# 3       adelie  torgersen                 4169                       8
# 4       adelie  torgersen                 4774                       8
# ..         ...        ...                  ...                     ...
# 339  chinstrap      dream                 4826                      11
# 340  chinstrap      dream                 4111                       9
# 341  chinstrap      dream                 7049                      10
# 342  chinstrap      dream                 4705                       7
# 343  chinstrap      dream                 6098                       7
#
#     bill_length_mm bill_depth_mm flipper_length_mm body_mass_g  gender    year
# ...

# %%
# Now we will replace the 'NaN' values with the mean values of the features
# As it will be less skewed.

for i in features_list:
  for j in range(0, pf_df_copy[i].count()):
    if (pf_df_copy[i][j] == 'NaN'):
      pf_df_copy[i][j] = np.nan
# Out:
# <ipython-input-139-fd405593c23a>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pf_df_copy[i][j] = np.nan

# %%
pf_df_copy
# Out:
#        species     island  calorie requirement  average sleep duration  \
# 0       adelie  torgersen                 6563                      11
# 1       adelie  torgersen                 4890                      14
# 2       adelie  torgersen                 7184                      11
# 3       adelie  torgersen                 4169                       8
# 4       adelie  torgersen                 4774                       8
# ..         ...        ...                  ...                     ...
# 339  chinstrap      dream                 4826                      11
# 340  chinstrap      dream                 4111                       9
# 341  chinstrap      dream                 7049                      10
# 342  chinstrap      dream                 4705                       7
# 343  chinstrap      dream                 6098                       7
#
#     bill_length_mm bill_depth_mm flipper_length_mm body_mass_g  gender    year
# ...

# %%
features_mean = []

for i in features_list:
  features_mean.append(pf_df_copy[i].mean())

for i,j in zip(features_list, features_mean):
    pf_df_copy[i].fillna(value = j, inplace = True)

# %%
# Here we can conclude that there will be non 'NaN' values
# in the dataset

# We will be showing a significant portion of the dataset to prove the above
# As the whole dataset cannot be shown in Google Colab (Thanks to Truncating !)

pf_df_copy
# Out:
#        species     island  calorie requirement  average sleep duration  \
# 0       adelie  torgersen                 6563                      11
# 1       adelie  torgersen                 4890                      14
# 2       adelie  torgersen                 7184                      11
# 3       adelie  torgersen                 4169                       8
# 4       adelie  torgersen                 4774                       8
# ..         ...        ...                  ...                     ...
# 339  chinstrap      dream                 4826                      11
# 340  chinstrap      dream                 4111                       9
# 341  chinstrap      dream                 7049                      10
# 342  chinstrap      dream                 4705                       7
# 343  chinstrap      dream                 6098                       7
#
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  gender  \
# ...

# %% [markdown]
# 6 🔽. Using any data visualization library (e.g. matplotlib, seaborn, plotly),
# provide at least 5 visualization graphs related to your dataset. You can utilize
# any columns or a combination of columns in your dataset to generate graphs.
#
# E.g. correlation matrix, features vs. the target, counts of categorical features
# vs. the target.

# %%
# 1. Scatter plot - between the features : body_mass_g vs calorie requirement

plt.scatter(pf_df_copy['body_mass_g'], pf_df_copy['calorie requirement'])
plt.title("Scatter plot : 'body_mass_g' VS 'calorie requirement'")
plt.xlabel("Body Mass G")
plt.ylabel("Calorie Requirement")
plt.show()

# %%
# 2. Area plot - for "average sleep duration"

pf_df_copy['average sleep duration'].plot.area()
plt.title("Area Plot fpr the feature 'average sleep duration'")
plt.ylabel("Average sleep duration")
plt.show()

# %%
# 3. Histogram - For observing the frequencies of the values of Bill Length

plt.hist(pf_df_copy['bill_length_mm'])
plt.title("Histogram for the feature 'bill_length_mm'")
plt.xlabel("bill_length_mm")
plt.show()

# %%
# 4. Box plot : Bill Length

plt.boxplot(pf_df_copy['bill_length_mm'])
plt.title("Box Plot for the feature 'bill_length_mm'")
plt.ylabel("bill_length_mm")
plt.show()

# %%
# 5. Violin plot : body_mass_g

sns.violinplot(data=pf_df_copy['body_mass_g'], color='skyblue')
plt.title("Violin Plot for the feature 'body_mass_g'")
plt.ylabel("body_mass_g")
plt.show()

# %%
'''
FOR INFORMATION 🌟

A violin plot, which depicts data peaks, is a cross between a box plot and a
kernel density plot. It is used to show how numerical data is distributed.
Violin plots provide summary statistics as well as the density of each variable,
unlike box plots, which can only show summary statistics.

A method for displaying the distribution of observations in a dataset is a
kernel density estimation plot.
'''
# Out:
# '\nFOR INFORMATION 🌟\n\nA violin plot, which depicts data peaks, is a cross between a box plot and a\nkernel density plot. It is used to show how numerical data is distributed.\nViolin plots provide summary statistics as well as the density of each variable,\nunlike box plots, which can only show summary statistics.\n\nA method for displaying the distribution of observations in a dataset is a\nkernel density estimation plot.\n'

# %% [markdown]
# 7 🔽. Identify uncorrelated or unrelated features.
#
# Unrelated or uncorrelated features can introduce confusion to your model and
# negatively impact its performance. You can compute the correlation matrix
# between the features and the target variable. Features with a low correlation
# coefficient should be identified and subsequently dropped from the dataset to
# enhance model performance.

# %%
# First we will try to obtain the correlation among the features
# of the dataset

cor_mat = pf_df_copy.corr()
heatMap = sns.heatmap(pf_df_copy.corr(), annot=True)
# Out:
# <ipython-input-48-55bccbfb00f2>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor_mat = pf_df_copy.corr()
# <ipython-input-48-55bccbfb00f2>:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   heatMap = sns.heatmap(pf_df_copy.corr(), annot=True)

# %%
# We can see that the feature "bill_length_mm" has negative correlation with
# every other feature that has numerical values. Thus, we should drop it

pf_df_copy = pf_df_copy.drop("calorie requirement", axis = 1)
pf_df_copy = pf_df_copy.drop("average sleep duration", axis = 1)
pf_df_copy = pf_df_copy.drop("year", axis = 1)

# %%
pf_df_copy
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       adelie  torgersen       39.100000      18.700000         181.000000
# 1       adelie  torgersen       39.500000      17.400000         186.000000
# 2       adelie  torgersen       40.300000      18.000000         195.000000
# 3       adelie  torgersen       45.494214      18.018318         197.764881
# 4       adelie  torgersen       36.700000      19.300000         193.000000
# ..         ...        ...             ...            ...                ...
# 339  chinstrap      dream       55.800000      19.800000         207.000000
# 340  chinstrap      dream       43.500000      18.100000         202.000000
# 341  chinstrap      dream       49.600000      18.200000         193.000000
# 342  chinstrap      dream       50.800000      19.000000         210.000000
# 343  chinstrap      dream       50.200000      18.700000         198.000000
#
#      body_mass_g  gender
# 0    3750.000000    male
# ...

# %% [markdown]
# 8 🔽. Convert features with string datatype to categorical (e.g., species, island, gender). Possible ways: </br></br>
#    • One-hot encoding, creating binary columns for each category, denoting their
#      presence or absence. E.g., in the "Species" feature, "Adelie," "Chinstrap,"
#      and "Gentoo" become binary columns with "1" for presence and "0" for
#      absence.</br>
#
#    • Label encoding assigns unique integers to distinct feature values, useful
#      for ordinal relationships among categories. E.g., "Small" as 0, "Medium"
#      as 1, and "Large" as 2 can represent a "Size" feature. However, it may
#      introduce unintended patterns.

# %%
# Let us move with the later option for converting the string data to categorical
# for easy analysis on the later stage. We will have to this task for all the

# We will take this code from "Assignment 0"

# 🔽 For "species" feature

pf_df_copy['species'] = pd.Categorical(pf_df_copy['species'])
pf_df_copy['species'] = pf_df_copy['species'].cat.codes
pf_df_copy
# Out:
#      species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0          0  torgersen       39.100000      18.700000         181.000000
# 1          0  torgersen       39.500000      17.400000         186.000000
# 2          0  torgersen       40.300000      18.000000         195.000000
# 3          0  torgersen       45.494214      18.018318         197.764881
# 4          0  torgersen       36.700000      19.300000         193.000000
# ..       ...        ...             ...            ...                ...
# 339        1      dream       55.800000      19.800000         207.000000
# 340        1      dream       43.500000      18.100000         202.000000
# 341        1      dream       49.600000      18.200000         193.000000
# 342        1      dream       50.800000      19.000000         210.000000
# 343        1      dream       50.200000      18.700000         198.000000
#
#      body_mass_g  gender
# 0    3750.000000    male
# 1    3800.000000  female
# ...

# %%
# 🔽 For "island" feature

pf_df_copy['island'] = pd.Categorical(pf_df_copy['island'])
pf_df_copy['island'] = pf_df_copy['island'].cat.codes
pf_df_copy
# Out:
#      species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0          0       2       39.100000      18.700000         181.000000
# 1          0       2       39.500000      17.400000         186.000000
# 2          0       2       40.300000      18.000000         195.000000
# 3          0       2       45.494214      18.018318         197.764881
# 4          0       2       36.700000      19.300000         193.000000
# ..       ...     ...             ...            ...                ...
# 339        1       1       55.800000      19.800000         207.000000
# 340        1       1       43.500000      18.100000         202.000000
# 341        1       1       49.600000      18.200000         193.000000
# 342        1       1       50.800000      19.000000         210.000000
# 343        1       1       50.200000      18.700000         198.000000
#
#      body_mass_g  gender
# 0    3750.000000    male
# 1    3800.000000  female
# 2    3250.000000  female
# ...

# %%
# 🔽 For "gender" feature

pf_df_copy['gender'] = pd.Categorical(pf_df_copy['gender'])
pf_df_copy['gender'] = pf_df_copy['gender'].cat.codes
pf_df_copy
# Out:
#      species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0          0       2       39.100000      18.700000         181.000000
# 1          0       2       39.500000      17.400000         186.000000
# 2          0       2       40.300000      18.000000         195.000000
# 3          0       2       45.494214      18.018318         197.764881
# 4          0       2       36.700000      19.300000         193.000000
# ..       ...     ...             ...            ...                ...
# 339        1       1       55.800000      19.800000         207.000000
# 340        1       1       43.500000      18.100000         202.000000
# 341        1       1       49.600000      18.200000         193.000000
# 342        1       1       50.800000      19.000000         210.000000
# 343        1       1       50.200000      18.700000         198.000000
#
#      body_mass_g  gender
# 0    3750.000000       1
# 1    3800.000000       0
# 2    3250.000000       0
# ...

# %% [markdown]
# 9 🔽. Normalize non-categorical features (e.g. bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g).</br>
#
#   a. Find the min and max values for each column.</br>
#   b. Rescale dataset columns to the range from 0 to 1</br>
#
# Why do we do this? Normalization is to transform features to be on a similar scale. This improves the performance and training stability of the model.
# Note: normalize() is not allowed as it is a part of scikit-learn library.

# %%
# Creating the list of minimum & maximum values of all the existing features
# that contain numerical values

# We are excluding the features, whose values
# were converted from string to categorical

feature_list = pf_df_copy.columns.tolist()
feature_list.remove('species')
feature_list.remove('island')
feature_list.remove('gender')

min_list = []
max_list = []
for i in feature_list:
  min_list.append(pf_df_copy[i].min())
  max_list.append(pf_df_copy[i].max())

# %%
# Printing the minimum & maximum values lists

print(min_list)
print(max_list)
# Out:
# [32.1, 13.1, 172.0, 2700.0]
# [59.6, 21.5, 231.0, 6300.0]

# %%
# Lets normalize the data

for i,k,l in zip(feature_list, min_list, max_list):
  for j in range(0, pf_df_copy[i].count()):
    pf_df_copy[i][j] = ((pf_df_copy[i][j] - k)/(l-k))
# Out:
# <ipython-input-56-b3847705210e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pf_df_copy[i][j] = ((pf_df_copy[i][j] - k)/(l-k))

# %%
# Lets check whether the data is normalized or not

pf_df_copy
# Out:
#      species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0          0       2        0.254545       0.666667           0.152542
# 1          0       2        0.269091       0.511905           0.237288
# 2          0       2        0.298182       0.583333           0.389831
# 3          0       2        0.487062       0.585514           0.436693
# 4          0       2        0.167273       0.738095           0.355932
# ..       ...     ...             ...            ...                ...
# 339        1       1        0.861818       0.797619           0.593220
# 340        1       1        0.414545       0.595238           0.508475
# 341        1       1        0.636364       0.607143           0.355932
# 342        1       1        0.680000       0.702381           0.644068
# 343        1       1        0.658182       0.666667           0.440678
#
#      body_mass_g  gender
# 0       0.291667       1
# 1       0.305556       0
# 2       0.152778       0
# ...

# %%
# Now here we have made a mistake - We normalized the values of the "year" feature
# This is the reason why we created a copy of the imported dataset
# and not went for modifying the original variable's dataset values

penguins_df

# You see that the values of the original variable where dataset is stored
# is still intact
# Out:
#        species     island  calorie requirement  average sleep duration  \
# 0       Adelie  Torgersen                 6563                      11
# 1       Adelie  Torgersen                 4890                      14
# 2       Adelie  Torgersen                 7184                      11
# 3       Adelie  Torgersen                 4169                       8
# 4       Adelie  Torgersen                 4774                       8
# ..         ...        ...                  ...                     ...
# 339  Chinstrap      Dream                 4826                      11
# 340  Chinstrap      Dream                 4111                       9
# 341  Chinstrap      Dream                 7049                      10
# 342  Chinstrap      Dream                 4705                       7
# 343  Chinstrap      Dream                 6098                       7
#
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  gender  \
# ...

# %%
# Now we will just copy & paste the values

pf_df_copy['year'] = penguins_df['year'].copy()

# %%
# Hence, everything looks good till now !

pf_df_copy
# Out:
#      species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0          0       2        0.254545       0.666667           0.152542
# 1          0       2        0.269091       0.511905           0.237288
# 2          0       2        0.298182       0.583333           0.389831
# 3          0       2        0.487062       0.585514           0.436693
# 4          0       2        0.167273       0.738095           0.355932
# ..       ...     ...             ...            ...                ...
# 339        1       1        0.861818       0.797619           0.593220
# 340        1       1        0.414545       0.595238           0.508475
# 341        1       1        0.636364       0.607143           0.355932
# 342        1       1        0.680000       0.702381           0.644068
# 343        1       1        0.658182       0.666667           0.440678
#
#      body_mass_g  gender    year
# 0       0.291667       1  2007.0
# 1       0.305556       0  2007.0
# ...

# %%
# We might need this dataset for later purposes
# Like for Part 2 of Assignment 1. Hence we will
# try to export it (but with a different name)

pf_df_copy.to_csv('penguins_preprocessed.csv')
# !cp penguins_preprocessed.csv "drive/My Drive/Datasets/"

# %% [markdown]
# 10 🔽. Select another dataset and complete Steps 1-9. In total, you need to provide the data analysis and preprocessing for TWO datasets: ‘penguins’ and any of your choice from the provided folder ‘noisy_datasets’.

# %% [markdown]
# 1 (A) 🔽. Import required libraries (not allowed: scikit-learn or any other libraries
# with in-built functions that help to implement ML methods)
#
# 2 (A) 🔽. Read, preprocess, and print the main statistics about the dataset (you can reuse your code from A0 with a proper citation)

# %%
# We will go with the dataset : "diamond.csv"

diamond_df = pd.read_csv("/content/drive/MyDrive/Datasets/diamond.csv")
diamond_df
# Out:
#       Unnamed: 0 carat        cut color clarity  average us salary  \
# 0              1  0.23      Ideal     E     SI2              31282
# 1              2  0.21    Premium     E     SI1              40049
# 2              3  0.23       Good     E     VS1              33517
# 3              4  0.29    Premium     I     VS2              38495
# 4              5  0.31       Good     J     SI2              34178
# ...          ...   ...        ...   ...     ...                ...
# 53935      53936  0.72      Ideal     D     SI1              43892
# 53936      53937  0.72       Good     D     SI1              35532
# 53937      53938   0.7  Very Good     D     SI1              32133
# 53938      53939  0.86    Premium     H     SI2              44248
# 53939      53940  0.75      Ideal     D     SI2              41412
#
#        number of diamonds mined (millions) depth table price     x     y     z
# 0                                     5.01  61.5    55   326  3.95  3.98  2.43
# ...

# %%
# We want to know the shape of the dataset

diamond_df.shape
# Out:
# (53940, 13)

# %%
# Printing the main statistics of the dataset - including mean, standard
# deviation, and other relevant statistics

# We have taken this piece of code from "Assignment 0"

diamond_df.describe()
# Out:
#        average us salary  number of diamonds mined (millions)
# count       53940.000000                         53940.000000
# mean        39521.990100                             2.902669
# std          5486.892971                             1.325985
# min         30000.000000                             0.600000
# 25%         34780.000000                             1.750000
# 50%         39547.500000                             2.910000
# 75%         44252.000000                             4.050000
# max         48999.000000                             5.200000

# %%
# Lets print the columns of the dataset

# We have taken this piece of code form "Assignment 0"

print(diamond_df.columns.tolist())
# Out:
# ['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'average us salary', 'number of diamonds mined (millions)', 'depth', 'table', 'price', 'x', 'y', 'z']

# %%
# Let us see the first 15 rows of the dataset - we just want to see a sample of
# the dataset (considering it as the population)

# We have taken this piece of code form "Assignment 0"

diamond_df.head(15)
# Out:
#    Unnamed: 0  carat        cut color clarity  average us salary  \
# 0           1   0.23      Ideal     E     SI2              31282
# 1           2   0.21    Premium     E     SI1              40049
# 2           3   0.23       Good     E     VS1              33517
# 3           4   0.29    Premium     I     VS2              38495
# 4           5   0.31       Good     J     SI2              34178
# 5           6   0.24  Very Good     J    VVS2              44700
# 6           7   0.24  Very Good     I    VVS1              42939
# 7           8  FALSE        NaN     H     SI1              37587
# 8           9   0.22       Fair     E     VS2              30454
# 9          10   0.23  Very Good     H     VS1              45506
# 10         11    0.3       Good     J     SI1              38031
# 11         12   0.23      Ideal     J     VS1              44410
# 12         13   0.22    Premium     F     SI1              43752
# ...

# %% [markdown]
# 3 (A) 🔽. Handle missing entries. Possible solutions:

# %%
# As the "penguins" datatset is not very large - we will try to impute
# the messing data using the mean of the features

# Lets have a copy of the dataset

diamond_df_copy = diamond_df.copy(deep=True)

# %%
features_list = diamond_df_copy.columns.tolist()
print(features_list)
# Out:
# ['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'average us salary', 'number of diamonds mined (millions)', 'depth', 'table', 'price', 'x', 'y', 'z']

# %%
# Drop the categorical features for the time being from the list

features_list.remove("cut")
features_list.remove("color")
features_list.remove("clarity")

# %%
print(features_list)
# Out:
# ['Unnamed: 0', 'carat', 'average us salary', 'number of diamonds mined (millions)', 'depth', 'table', 'price', 'x', 'y', 'z']

# %%
# I am also removing the feature "Unnamed: 0" as it is just a feature of serial
# numbers

features_list.remove("Unnamed: 0")

# %%
features_list
# Out:
# ['carat',
#  'average us salary',
#  'number of diamonds mined (millions)',
#  'depth',
#  'table',
#  'price',
#  'x',
#  'y',
#  'z']

# %%
# Lets find the mean values of the features left in the dataset.

features_mean = []

# After observation on the values of the dataset, we have noticed & assumed that
# the numerical values are also stored as "string" and also there are some
# values which are actually "string" : like "FALSE"

for i in features_list:
  feature_sum = 0
  for j in range(0, 53940):
    try:
      if (diamond_df_copy[i][j].isnumeric()):
        feature_sum += float(diamond_df_copy[i][j])
    except:
      continue

  features_mean.append(feature_sum/53940)

# %%
features_mean
# Out:
# [0.03735632183908046,
#  0.0,
#  0.0,
#  6.0013348164627365,
#  53.44827586206897,
#  3780.1927141268075,
#  0.02532443455691509,
#  0.031757508342602894,
#  0.05628476084538376]

# %%
# Calculating mean value for "average us salary"

features_mean[1] = diamond_df_copy['average us salary'].mean()

# %%
features_mean
# Out:
# [0.03735632183908046,
#  39521.99010011124,
#  0.0,
#  6.0013348164627365,
#  53.44827586206897,
#  3780.1927141268075,
#  0.02532443455691509,
#  0.031757508342602894,
#  0.05628476084538376]

# %%
# Calculating mean value for "number of diamonds mined (millions)"

features_mean[2] = diamond_df_copy['number of diamonds mined (millions)'].mean()

# %%
features_mean
# Out:
# [0.03735632183908046,
#  39521.99010011124,
#  2.9026694475342976,
#  6.0013348164627365,
#  53.44827586206897,
#  3780.1927141268075,
#  0.02532443455691509,
#  0.031757508342602894,
#  0.05628476084538376]

# %%
# Now, we are confident that the features :
# "average us salary" and "number of diamonds mined (millions)"
# have all numerical values

# Thus, we can now replace the non-numerical values
# with the respective mean values of the features

feature_mean_dict = dict(zip(features_list, features_mean))

for i in features_list:
  for j in range(0, 53940):
    if (isinstance(diamond_df_copy[i][j], str) and not(diamond_df_copy[i][j].replace(".","").isnumeric())):
        diamond_df_copy[i][j] = feature_mean_dict[i]
    else:
      continue
# Out:
# <ipython-input-79-5967a0a9b324>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamond_df_copy[i][j] = feature_mean_dict[i]

# %%
# Lets have a look to the modified dataset

diamond_df_copy
# Out:
#       Unnamed: 0 carat        cut color clarity  average us salary  \
# 0              1  0.23      Ideal     E     SI2              31282
# 1              2  0.21    Premium     E     SI1              40049
# 2              3  0.23       Good     E     VS1              33517
# 3              4  0.29    Premium     I     VS2              38495
# 4              5  0.31       Good     J     SI2              34178
# ...          ...   ...        ...   ...     ...                ...
# 53935      53936  0.72      Ideal     D     SI1              43892
# 53936      53937  0.72       Good     D     SI1              35532
# 53937      53938   0.7  Very Good     D     SI1              32133
# 53938      53939  0.86    Premium     H     SI2              44248
# 53939      53940  0.75      Ideal     D     SI2              41412
#
#        number of diamonds mined (millions) depth table price     x     y     z
# 0                                     5.01  61.5    55   326  3.95  3.98  2.43
# ...

# %%
# Lets have a look into the categorical features of the dataset
# Assuming that they still have "NaN" values - lets just replace them
# with valid values

diamond_df_copy['cut'] = diamond_df_copy['cut'].fillna(method = 'ffill')

# %%
diamond_df_copy
# Out:
#       Unnamed: 0 carat        cut color clarity  average us salary  \
# 0              1  0.23      Ideal     E     SI2              31282
# 1              2  0.21    Premium     E     SI1              40049
# 2              3  0.23       Good     E     VS1              33517
# 3              4  0.29    Premium     I     VS2              38495
# 4              5  0.31       Good     J     SI2              34178
# ...          ...   ...        ...   ...     ...                ...
# 53935      53936  0.72      Ideal     D     SI1              43892
# 53936      53937  0.72       Good     D     SI1              35532
# 53937      53938   0.7  Very Good     D     SI1              32133
# 53938      53939  0.86    Premium     H     SI2              44248
# 53939      53940  0.75      Ideal     D     SI2              41412
#
#        number of diamonds mined (millions) depth table price     x     y     z
# 0                                     5.01  61.5    55   326  3.95  3.98  2.43
# ...

# %%
diamond_df_copy['color'] = diamond_df_copy['color'].fillna(method = 'ffill')
diamond_df_copy['clarity'] = diamond_df_copy['clarity'].fillna(method = 'ffill')
diamond_df_copy
# Out:
#       Unnamed: 0 carat        cut color clarity  average us salary  \
# 0              1  0.23      Ideal     E     SI2              31282
# 1              2  0.21    Premium     E     SI1              40049
# 2              3  0.23       Good     E     VS1              33517
# 3              4  0.29    Premium     I     VS2              38495
# 4              5  0.31       Good     J     SI2              34178
# ...          ...   ...        ...   ...     ...                ...
# 53935      53936  0.72      Ideal     D     SI1              43892
# 53936      53937  0.72       Good     D     SI1              35532
# 53937      53938   0.7  Very Good     D     SI1              32133
# 53938      53939  0.86    Premium     H     SI2              44248
# 53939      53940  0.75      Ideal     D     SI2              41412
#
#        number of diamonds mined (millions) depth table price     x     y     z
# 0                                     5.01  61.5    55   326  3.95  3.98  2.43
# ...

# %% [markdown]
# 4 (A) 🔽. Handle mismatched string formats.

# %%
# Here we are converting the necessary categorical values of all the features
# into their lower case - to maintain consistency

feature_list = ['cut']

for i in feature_list:
  for j in range(0, 53940):
    diamond_df_copy[i][j] = diamond_df_copy[i][j].lower()
# Out:
# <ipython-input-84-1b57ed07236f>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamond_df_copy[i][j] = diamond_df_copy[i][j].lower()

# %%
diamond_df_copy
# Out:
#       Unnamed: 0 carat        cut color clarity  average us salary  \
# 0              1  0.23      ideal     E     SI2              31282
# 1              2  0.21    premium     E     SI1              40049
# 2              3  0.23       good     E     VS1              33517
# 3              4  0.29    premium     I     VS2              38495
# 4              5  0.31       good     J     SI2              34178
# ...          ...   ...        ...   ...     ...                ...
# 53935      53936  0.72      ideal     D     SI1              43892
# 53936      53937  0.72       good     D     SI1              35532
# 53937      53938   0.7  very good     D     SI1              32133
# 53938      53939  0.86    premium     H     SI2              44248
# 53939      53940  0.75      ideal     D     SI2              41412
#
#        number of diamonds mined (millions) depth table price     x     y     z
# 0                                     5.01  61.5    55   326  3.95  3.98  2.43
# ...

# %% [markdown]
# 5 (A) 🔽. Handle outliers. Detect and manage outliers within the dataset.

# %%
# Please note : outliers for features that contain categorical values
# doesn't make any sense. Thus, we will stick to the features that
# contain numerical values

# Lets see what all features have numerical values

print(features_list)
# Out:
# ['carat', 'average us salary', 'number of diamonds mined (millions)', 'depth', 'table', 'price', 'x', 'y', 'z']

# %%
# Let us drop the "Unnamed: 0" feature as it only contains
# sequential numbers

diamond_df_copy = diamond_df_copy.drop("Unnamed: 0", axis = 1)

# %%
# We will first create box plots to see abnormal values

# Lets first print the features list

print(features_list)
# Out:
# ['carat', 'average us salary', 'number of diamonds mined (millions)', 'depth', 'table', 'price', 'x', 'y', 'z']

# %%
diamond_df_copy
# Out:
#       carat        cut color clarity  average us salary  \
# 0      0.23      ideal     E     SI2              31282
# 1      0.21    premium     E     SI1              40049
# 2      0.23       good     E     VS1              33517
# 3      0.29    premium     I     VS2              38495
# 4      0.31       good     J     SI2              34178
# ...     ...        ...   ...     ...                ...
# 53935  0.72      ideal     D     SI1              43892
# 53936  0.72       good     D     SI1              35532
# 53937   0.7  very good     D     SI1              32133
# 53938  0.86    premium     H     SI2              44248
# 53939  0.75      ideal     D     SI2              41412
#
#        number of diamonds mined (millions) depth table price     x     y     z
# 0                                     5.01  61.5    55   326  3.95  3.98  2.43
# 1                                     1.69  59.8    61   326  3.89  3.84  2.31
# ...

# %%
# The price feature still has "NaN" values - but we won't be able
# to replace them with the mean value because the values
# are in ascending order

diamond_df_copy['price'] = diamond_df_copy['price'].fillna(method = "ffill")

# %%
# Assuming that many values are still in the form of
# strings - Thus, we have to change them as well

diamond_df_copy['carat'] = diamond_df_copy['carat'].astype(float)
diamond_df_copy['average us salary'] = diamond_df_copy['average us salary'].astype(int)
diamond_df_copy['number of diamonds mined (millions)'] = diamond_df_copy['number of diamonds mined (millions)'].astype(float)
diamond_df_copy['depth'] = diamond_df_copy['depth'].astype(float)
diamond_df_copy['table'] = diamond_df_copy['table'].astype(float)
diamond_df_copy['price'] = diamond_df_copy['price'].astype(int)
diamond_df_copy['x'] = diamond_df_copy['x'].astype(float)
diamond_df_copy['y'] = diamond_df_copy['y'].astype(float)
diamond_df_copy['z'] = diamond_df_copy['z'].astype(float)

# %%
# Lets create box-plots

for i in features_list:
  print(i + "🔽")
  print("MIN : ", diamond_df_copy[i].min())
  print("MAX : ", diamond_df_copy[i].max())
  plt.boxplot(diamond_df_copy[i])
  plt.show()
# Out:
# carat🔽
# MIN :  0.03735632183908046
# MAX :  5.01
# average us salary🔽
# MIN :  30000
# MAX :  48999
# number of diamonds mined (millions)🔽
# MIN :  0.6
# MAX :  5.2
# depth🔽
# MIN :  6.0013348164627365
# MAX :  79.0
# table🔽
# MIN :  43.0
# MAX :  95.0
# price🔽
# MIN :  326
# MAX :  18823
# x🔽
# MIN :  0.0
# MAX :  10.74
# y🔽
# MIN :  0.0
# MAX :  58.9
# z🔽
# MIN :  0.0
# MAX :  31.8

# %%
# We can see that there are still "NaN" values left - That's why
# we are not getting the boxplots. Thus we need to remove them.

new_features_list = ['carat', 'depth', 'table', 'x', 'y', 'z']

for i in new_features_list:
  if np.isnan(diamond_df_copy[i]).any():
    diamond_df_copy[i] = diamond_df_copy[i].fillna(method = 'ffill')

# %%
# Lets create the boxplots again !

for i in features_list:
  print("\n\n\n" + i + "🔽")
  print("MIN : ", diamond_df_copy[i].min())
  print("MAX : ", diamond_df_copy[i].max())
  plt.boxplot(diamond_df_copy[i])
  plt.show()
# Out:
# carat🔽
# MIN :  0.03735632183908046
# MAX :  5.01
# average us salary🔽
# MIN :  30000
# MAX :  48999
# number of diamonds mined (millions)🔽
# MIN :  0.6
# MAX :  5.2
# depth🔽
# MIN :  6.0013348164627365
# MAX :  79.0
# table🔽
# MIN :  43.0
# MAX :  95.0
# price🔽
# MIN :  326
# MAX :  18823
# x🔽
# MIN :  0.0
# MAX :  10.74
# y🔽
# MIN :  0.0
# MAX :  58.9
# z🔽
# MIN :  0.0
# MAX :  31.8

# %%
# We need to remove all the outliers from all the features / columns
# Thus, we need a function for the same

def outliers_removal(feature):
    Q1 = np.percentile(feature, 25)
    Q3 = np.percentile(feature, 75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    cleaned_data = []
    # cleaned_data = [i for i in feature if lower_bound <= i <= upper_bound]
    for i in feature:
      if (lower_bound <= i <= upper_bound):
        cleaned_data.append(i)
      else:
        cleaned_data.append('NaN')

    return cleaned_data

# Now lets put this function into action !

for i in features_list:
  diamond_df_copy[i] = outliers_removal(diamond_df_copy[i])

# %%
# Lets print the dataset

diamond_df_copy
# Out:
#       carat        cut color clarity  average us salary  \
# 0      0.23      ideal     E     SI2              31282
# 1      0.21    premium     E     SI1              40049
# 2      0.23       good     E     VS1              33517
# 3      0.29    premium     I     VS2              38495
# 4      0.31       good     J     SI2              34178
# ...     ...        ...   ...     ...                ...
# 53935  0.72      ideal     D     SI1              43892
# 53936  0.72       good     D     SI1              35532
# 53937   0.7  very good     D     SI1              32133
# 53938  0.86    premium     H     SI2              44248
# 53939  0.75      ideal     D     SI2              41412
#
#        number of diamonds mined (millions) depth table price     x     y     z
# 0                                     5.01  61.5  55.0   326  3.95  3.98  2.43
# 1                                     1.69  59.8  61.0   326  3.89  3.84  2.31
# ...

# %%
# Now we will replace the 'NaN' values with the mean values of the features
# As it will be less skewed.

for i in features_list:
  for j in range(0, diamond_df_copy[i].count()):
    if (diamond_df_copy[i][j] == 'NaN'):
      diamond_df_copy[i][j] = np.nan
# Out:
# <ipython-input-97-2c8e0562bc66>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamond_df_copy[i][j] = np.nan

# %%
diamond_df_copy
# Out:
#       carat        cut color clarity  average us salary  \
# 0      0.23      ideal     E     SI2              31282
# 1      0.21    premium     E     SI1              40049
# 2      0.23       good     E     VS1              33517
# 3      0.29    premium     I     VS2              38495
# 4      0.31       good     J     SI2              34178
# ...     ...        ...   ...     ...                ...
# 53935  0.72      ideal     D     SI1              43892
# 53936  0.72       good     D     SI1              35532
# 53937   0.7  very good     D     SI1              32133
# 53938  0.86    premium     H     SI2              44248
# 53939  0.75      ideal     D     SI2              41412
#
#        number of diamonds mined (millions) depth table price     x     y     z
# 0                                     5.01  61.5  55.0   326  3.95  3.98  2.43
# 1                                     1.69  59.8  61.0   326  3.89  3.84  2.31
# ...

# %%
features_mean = []

for i in features_list:
  features_mean.append(diamond_df_copy[i].mean())

for i,j in zip(features_list, features_mean):
    diamond_df_copy[i].fillna(value = j, inplace = True)

# %%
# Here we can conclude that there will be non 'NaN' values
# in the dataset

# We will be showing a significant portion of the dataset to prove the above
# As the whole dataset cannot be shown in Google Colab (Thanks to Truncating !)

diamond_df_copy
# Out:
#        carat        cut color clarity  average us salary  \
# 0       0.23      ideal     E     SI2              31282
# 1       0.21    premium     E     SI1              40049
# 2       0.23       good     E     VS1              33517
# 3       0.29    premium     I     VS2              38495
# 4       0.31       good     J     SI2              34178
# ...      ...        ...   ...     ...                ...
# 53935   0.72      ideal     D     SI1              43892
# 53936   0.72       good     D     SI1              35532
# 53937   0.70  very good     D     SI1              32133
# 53938   0.86    premium     H     SI2              44248
# 53939   0.75      ideal     D     SI2              41412
#
#        number of diamonds mined (millions)      depth      table   price  \
# 0                                     5.01  61.500000  55.000000   326.0
# 1                                     1.69  59.800000  61.000000   326.0
# ...

# %% [markdown]
# 6 (A) 🔽. Data Visualization(s)

# %%
# 1. Scatter plot - between the features :
# "number of diamonds mined (millions)" vs "z"

plt.scatter(diamond_df_copy['number of diamonds mined (millions)'], diamond_df_copy['z'])
plt.title("Scatter plot : 'number of diamonds mined (millions)' VS 'z' ")
plt.xlabel("number of diamonds mined (millions)")
plt.ylabel("z values")
plt.show()

# %%
# 2. Area plot for price

diamond_df_copy['price'].plot.area()
plt.title("Area Plot for the feature \"price\"")
plt.xlabel("Price values")
plt.show()

# %%
# 3. Box plot for number of diamonds mined (millions)

plt.boxplot(diamond_df_copy['number of diamonds mined (millions)'])
plt.title("Box Plot for the feature \"number of diamonds mined (millions)\"")
plt.ylabel("number of diamonds mined (millions)")
plt.show()

# %%
# 4. Violin plot : 'y'

sns.violinplot(data=diamond_df_copy['y'], color='skyblue')
plt.title("Violin Plot for the feature \"y\"")
plt.ylabel("'y' values")
plt.show()

# %%
# 5. DENSITY PLOT

# Creating a density plot
sns.kdeplot(diamond_df_copy['depth'], shade=True, color="blue")

# Setting axis labels and plot title
plt.xlabel("Depth")
plt.ylabel("Density")
plt.title("Density Plot of feature \"Depth\"")

# Show the plot
plt.show()
# Out:
# <ipython-input-105-64991c18cfb2>:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(diamond_df_copy['depth'], shade=True, color="blue")

# %% [markdown]
# 7 (A) 🔽. Identify uncorrelated or unrelated features.

# %% [markdown]
# 8 🔽. Convert features with string datatype to categorical

# %%
# Let us move with the later option for converting the string data to categorical
# for easy analysis on the later stage. We will have to this task for all the

# We will take this code from "Assignment 0"

# 🔽 For "cut" feature

diamond_df_copy['cut'] = pd.Categorical(diamond_df_copy['cut'])
diamond_df_copy['cut'] = diamond_df_copy['cut'] .cat.codes
diamond_df_copy
# Out:
#        carat  cut color clarity  average us salary  \
# 0       0.23    3     E     SI2              31282
# 1       0.21    5     E     SI1              40049
# 2       0.23    2     E     VS1              33517
# 3       0.29    5     I     VS2              38495
# 4       0.31    2     J     SI2              34178
# ...      ...  ...   ...     ...                ...
# 53935   0.72    3     D     SI1              43892
# 53936   0.72    2     D     SI1              35532
# 53937   0.70    7     D     SI1              32133
# 53938   0.86    5     H     SI2              44248
# 53939   0.75    3     D     SI2              41412
#
#        number of diamonds mined (millions)      depth      table   price  \
# 0                                     5.01  61.500000  55.000000   326.0
# 1                                     1.69  59.800000  61.000000   326.0
# 2                                     3.85  61.776187  57.270887   327.0
# ...

# %%
# 🔽 For "color" feature

diamond_df_copy['color'] = pd.Categorical(diamond_df_copy['color'])
diamond_df_copy['color'] = diamond_df_copy['color'] .cat.codes
diamond_df_copy
# Out:
#        carat  cut  color clarity  average us salary  \
# 0       0.23    3      1     SI2              31282
# 1       0.21    5      1     SI1              40049
# 2       0.23    2      1     VS1              33517
# 3       0.29    5      6     VS2              38495
# 4       0.31    2      7     SI2              34178
# ...      ...  ...    ...     ...                ...
# 53935   0.72    3      0     SI1              43892
# 53936   0.72    2      0     SI1              35532
# 53937   0.70    7      0     SI1              32133
# 53938   0.86    5      5     SI2              44248
# 53939   0.75    3      0     SI2              41412
#
#        number of diamonds mined (millions)      depth      table   price  \
# 0                                     5.01  61.500000  55.000000   326.0
# 1                                     1.69  59.800000  61.000000   326.0
# 2                                     3.85  61.776187  57.270887   327.0
# ...

# %%
# 🔽 For "clarity" feature

diamond_df_copy['clarity'] = pd.Categorical(diamond_df_copy['clarity'])
diamond_df_copy['clarity'] = diamond_df_copy['clarity'] .cat.codes
diamond_df_copy
# Out:
#        carat  cut  color  clarity  average us salary  \
# 0       0.23    3      1        5              31282
# 1       0.21    5      1        4              40049
# 2       0.23    2      1        7              33517
# 3       0.29    5      6        8              38495
# 4       0.31    2      7        5              34178
# ...      ...  ...    ...      ...                ...
# 53935   0.72    3      0        4              43892
# 53936   0.72    2      0        4              35532
# 53937   0.70    7      0        4              32133
# 53938   0.86    5      5        5              44248
# 53939   0.75    3      0        5              41412
#
#        number of diamonds mined (millions)      depth      table   price  \
# 0                                     5.01  61.500000  55.000000   326.0
# 1                                     1.69  59.800000  61.000000   326.0
# 2                                     3.85  61.776187  57.270887   327.0
# ...

# %%
# First we will try to obtain the correlation between the features
# of the dataset. This can be represented using the heatmap

'''
cor_mat = diamond_df_copy.corr()
print(cor_mat)
'''
heatMap = sns.heatmap(diamond_df_copy.corr(), annot=True)

# %%
# As per the correlation matrix (generated using heatmap), we can infer that
# many features have ZERO or NEAR-ZERO correlation with other features.
# This may eventually hamper our analysis procedure - thus, they are to be dropped

diamond_df_copy = diamond_df_copy.drop(columns = ["cut", "clarity", "average us salary", "number of diamonds mined (millions)", "depth"], axis = 1)
diamond_df_copy
# Out:
#        carat  color      table   price     x     y     z
# 0       0.23      1  55.000000   326.0  3.95  3.98  2.43
# 1       0.21      1  61.000000   326.0  3.89  3.84  2.31
# 2       0.23      1  57.270887   327.0  4.05  4.07  2.31
# 3       0.29      6  58.000000   334.0  4.20  4.23  2.63
# 4       0.31      7  58.000000   335.0  4.34  4.35  2.75
# ...      ...    ...        ...     ...   ...   ...   ...
# 53935   0.72      0  57.000000  2757.0  5.75  5.76  3.50
# 53936   0.72      0  55.000000  2757.0  5.69  5.75  3.61
# 53937   0.70      0  60.000000  2757.0  5.66  5.68  3.56
# 53938   0.86      5  58.000000  2757.0  6.15  6.12  3.74
# 53939   0.75      0  55.000000  2757.0  5.83  5.87  3.64
#
# [53940 rows x 7 columns]

# %% [markdown]
# 9 🔽. Normalize non-categorical features

# %%
# Creating a fresh features list
features_list = diamond_df_copy.columns.tolist()
features_list
# Out:
# ['carat', 'color', 'table', 'price', 'x', 'y', 'z']

# %%
# We do not need to normalize categorical data
# So, lets drop them from them from the list

features_list.remove("color")
features_list
# Out:
# ['carat', 'table', 'price', 'x', 'y', 'z']

# %%
# Creating the list of minimum & maximum values of all the existing features
# that contain numerical values

# We are excluding the features, which were removed from the
# dataset because of negative correlation

min_list = []
max_list = []
for i in features_list:
  min_list.append(diamond_df_copy[i].min())
  max_list.append(diamond_df_copy[i].max())

# %%
# Printing the minimum & maximum values lists

print(min_list)
print(max_list)
# Out:
# [0.03735632183908046, 51.6, 326.0, 3.73, 3.68, 1.41]
# [2.0, 63.5, 11790.0, 9.3, 9.26, 5.75]

# %%
# Lets normalize the data

for i,k,l in zip(features_list, min_list, max_list):
  for j in range(0, 53940):
    diamond_df_copy[i][j] = ((diamond_df_copy[i][j] - k)/(l-k))
# Out:
# <ipython-input-108-0fe1e6bcae63>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diamond_df_copy[i][j] = ((diamond_df_copy[i][j] - k)/(l-k))

# %%
# Lets check whether the data is normalized or not

diamond_df_copy
# Out:
#           carat  color     table     price         x         y         z
# 0      0.098155      1  0.285714  0.000000  0.039497  0.053763  0.235023
# 1      0.087965      1  0.789916  0.000000  0.028725  0.028674  0.207373
# 2      0.098155      1  0.476545  0.000087  0.057451  0.069892  0.207373
# 3      0.128726      6  0.537815  0.000698  0.084381  0.098566  0.281106
# 4      0.138917      7  0.537815  0.000785  0.109515  0.120072  0.308756
# ...         ...    ...       ...       ...       ...       ...       ...
# 53935  0.347818      0  0.453782  0.212055  0.362657  0.372760  0.481567
# 53936  0.347818      0  0.285714  0.212055  0.351885  0.370968  0.506912
# 53937  0.337628      0  0.705882  0.212055  0.346499  0.358423  0.495392
# 53938  0.419151      5  0.537815  0.212055  0.434470  0.437276  0.536866
# 53939  0.363104      0  0.285714  0.212055  0.377020  0.392473  0.513825
#
# [53940 rows x 7 columns]

# %%
# Lets save this preprocessed dataset for future usage

diamond_df_copy.to_csv('diamond_preprocessed.csv')
# !cp diamond_preprocessed.csv "drive/My Drive/Datasets/"
